# %% [markdown]
# # Chapter 6 学習に関するテクニック

# %% [markdown]
# 1. パラメータの更新
# 2. 重みの初期値
# 3. Batch Normalization
# 4. 正則化
# 5. ハイパーパラメータの検証

# %% [markdown]
# ## SGD

# %%
import numpy as np

class SGD:

    """確率的勾配降下法（Stochastic Gradient Descent）"""

    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %% [markdown]
# ## Momentum

# %%
class Momentum:

    """Momentum SGD"""

    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():                                
                self.v[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key] 
            params[key] += self.v[key]

# %% [markdown]
# ## AdaGrad

# %%
class AdaGrad:

    """AdaGrad"""

    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
            
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %% [markdown]
# ## Adam

# %%
class Adam:

    """Adam (http://arxiv.org/abs/1412.6980v8)"""

    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
        
    def update(self, params, grads):
        if self.m is None:
            self.m, self.v = {}, {}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)
        
        self.iter += 1
        lr_t  = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)         
        
        for key in params.keys():
            #self.m[key] = self.beta1*self.m[key] + (1-self.beta1)*grads[key]
            #self.v[key] = self.beta2*self.v[key] + (1-self.beta2)*(grads[key]**2)
            self.m[key] += (1 - self.beta1) * (grads[key] - self.m[key])
            self.v[key] += (1 - self.beta2) * (grads[key]**2 - self.v[key])
            
            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + 1e-7)
            
            #unbias_m += (1 - self.beta1) * (grads[key] - self.m[key]) # correct bias
            #unbisa_b += (1 - self.beta2) * (grads[key]*grads[key] - self.v[key]) # correct bias
            #params[key] += self.lr * unbias_m / (np.sqrt(unbisa_b) + 1e-7)

# %% [markdown]
# ## MNISTでの更新手法の比較

# %%
import os
import sys
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0:MNISTデータの読み込み==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1:実験の設定==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2:訓練の開始==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3.グラフの描画==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# AdaGrad:2.081001484596368
# Adam:2.189934098689549
# SGD:2.317584437040858
# Momentum:2.389142397342178
# ===========iteration:100===========
# AdaGrad:0.07999967002166934
# Adam:0.17551311219629986
# SGD:1.7333379114205503
# Momentum:0.275038886722421
# ===========iteration:200===========
# AdaGrad:0.1181645480558409
# Adam:0.18137890661317912
# SGD:0.929017883940217
# Momentum:0.31057601786972056
# ===========iteration:300===========
# AdaGrad:0.11105815341784231
# Adam:0.16576174932588672
# SGD:0.5714885730872616
# Momentum:0.20706763927907879
# ===========iteration:400===========
# AdaGrad:0.07251757027143801
# Adam:0.1468249356204959
# SGD:0.4992194141549316
# Momentum:0.1737325262071065
# ===========iteration:500===========
# AdaGrad:0.030042848858275698
# Adam:0.0764679253633216
# SGD:0.3370926232015267
# Momentum:0.10852494032770285
# ===========iteration:600===========
# AdaGrad:0.0876052849696647
# Adam:0.16599986082463647
# SGD:0.42298325707942147
# Momentum:0.20144582190018778
# ===========iteration:700===========
# AdaGrad:0.03200751720361034
# Adam:0.05739092822890784
# SGD:0.26887017968517996
# Momentum:0.06660865390009703
# ===========iteration:800===========
# AdaGrad:0.025354410093245218
# Adam:0.08577131101241792
# SGD:0.29969697434277265
# Momentum:0.1096304815645826
# ===========iteration:900===========
# AdaGrad:0.06488379757312315
# Adam:0.1521986081460083
# SGD:0.3519631626284454
# Momentum:0.16224114105037085
# ===========iteration:1000===========
# AdaGrad:0.04494491343285035
# Adam:0.05293402361482774
# SGD:0.42491565859230734
# Momentum:0.11401885894153406
# ===========iteration:1100===========
# AdaGrad:0.05958071977775367
# Adam:0.07952904309332182
# SGD:0.33470436696822087
# Momentum:0.14517662218187175
# ===========iteration:1200===========
# AdaGrad:0.027105344052728665
# Adam:0.04550440149180217
# SGD:0.22751022951844782
# Momentum:0.06975656202377706
# ===========iteration:1300===========
# AdaGrad:0.1552428033474247
# Adam:0.21431781181788723
# SGD:0.30906126749002605
# Momentum:0.21229853411115823
# ===========iteration:1400===========
# AdaGrad:0.0246480190159495
# Adam:0.05921051155812506
# SGD:0.22805045374794722
# Momentum:0.07563915531672338
# ===========iteration:1500===========
# AdaGrad:0.03280145394318296
# Adam:0.04945749177461047
# SGD:0.2614386024510253
# Momentum:0.12857214414990678
# ===========iteration:1600===========
# AdaGrad:0.042170888814716256
# Adam:0.056661257223115866
# SGD:0.2003203761714179
# Momentum:0.10871002380506607
# ===========iteration:1700===========
# AdaGrad:0.016845089733101323
# Adam:0.010680860778645527
# SGD:0.18787263912592175
# Momentum:0.04325940537943744
# ===========iteration:1800===========
# AdaGrad:0.1320678934511038
# Adam:0.1471382428163177
# SGD:0.35422418289761987
# Momentum:0.25247509697428006
# ===========iteration:1900===========
# AdaGrad:0.07088493298034963
# Adam:0.0673317647494456
# SGD:0.26514633147587585
# Momentum:0.07390113292864722

# %% [markdown]
# ## MNISTデータセットによる重み初期値の比較
# - 左右対称で中央付近が線形関数：Xaviarの初期値 sqrt(1/n)
# - ReLU：Heの初期値 sqrt(2/n)

# %%
# 0:MNISTデータの読み込み==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1:実験の設定==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2:訓練の開始==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3.グラフの描画==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# Xavier:2.299471857894633
# He:2.3129771075359162
# std=0.01:2.302523736835808
# ===========iteration:100===========
# Xavier:2.2484869962764504
# He:1.5037098071936394
# std=0.01:2.302261446074694
# ===========iteration:200===========
# Xavier:2.129376260759245
# He:0.8216576728620638
# std=0.01:2.3033539047525666
# ===========iteration:300===========
# Xavier:1.8504264823787686
# He:0.4948490810344743
# std=0.01:2.3033504420465176
# ===========iteration:400===========
# Xavier:1.2483274321323896
# He:0.4368014468352955
# std=0.01:2.299785439335817
# ===========iteration:500===========
# Xavier:0.8953211142340891
# He:0.5262370105345399
# std=0.01:2.299020719759671
# ===========iteration:600===========
# Xavier:0.6690846779875549
# He:0.39119107341797543
# std=0.01:2.301403922029584
# ===========iteration:700===========
# Xavier:0.5997990360842136
# He:0.3062847101318577
# std=0.01:2.300985711367492
# ===========iteration:800===========
# Xavier:0.4967518853159868
# He:0.27551095108158985
# std=0.01:2.302909934988474
# ===========iteration:900===========
# Xavier:0.46410315833769644
# He:0.31789007682009496
# std=0.01:2.30311408647492
# ===========iteration:1000===========
# Xavier:0.3981456551266278
# He:0.30204840762454366
# std=0.01:2.3051832081234673
# ===========iteration:1100===========
# Xavier:0.4038602843049287
# He:0.32180422309933343
# std=0.01:2.2995500259496233
# ===========iteration:1200===========
# Xavier:0.348120725408704
# He:0.2901478687117225
# std=0.01:2.3017956472274452
# ===========iteration:1300===========
# Xavier:0.23679858798866615
# He:0.14900200440567904
# std=0.01:2.3037748125440913
# ===========iteration:1400===========
# Xavier:0.34354562195743554
# He:0.22251230195594002
# std=0.01:2.304760498340923
# ===========iteration:1500===========
# Xavier:0.37063197347885707
# He:0.3249753342678585
# std=0.01:2.2973423746921284
# ===========iteration:1600===========
# Xavier:0.3361689339345418
# He:0.20778373400673977
# std=0.01:2.3008908164497406
# ===========iteration:1700===========
# Xavier:0.3532123113370715
# He:0.24578946049179862
# std=0.01:2.3010118885665682
# ===========iteration:1800===========
# Xavier:0.25348903171456694
# He:0.1933466829436144
# std=0.01:2.304432554869998
# ===========iteration:1900===========
# Xavier:0.3107934441281
# He:0.19308402720993853
# std=0.01:2.296000278054044

# %% [markdown]
# ## Batch Normalizationの評価

# %%
from common.multi_layer_net_extend import MultiLayerNetExtend

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 学習データを削減
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 3.グラフの描画==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.097 - 0.086
# ../common/multi_layer_net_extend.py:101: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../common/multi_layer_net_extend.py:101: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:1 | 0.117 - 0.094
# epoch:2 | 0.117 - 0.113
# epoch:3 | 0.117 - 0.126
# epoch:4 | 0.117 - 0.136
# epoch:5 | 0.117 - 0.152
# epoch:6 | 0.117 - 0.165
# epoch:7 | 0.117 - 0.194
# epoch:8 | 0.117 - 0.206
# epoch:9 | 0.117 - 0.207
# epoch:10 | 0.117 - 0.234
# epoch:11 | 0.117 - 0.252
# epoch:12 | 0.117 - 0.272
# epoch:13 | 0.117 - 0.285
# epoch:14 | 0.117 - 0.298
# epoch:15 | 0.117 - 0.312
# epoch:16 | 0.116 - 0.333
# epoch:17 | 0.117 - 0.348
# epoch:18 | 0.117 - 0.365
# epoch:19 | 0.117 - 0.385
# No handles with labels found to put in legend.
# ../common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# /Users/nishimuranaoki/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ============== 2/16 ==============
# epoch:0 | 0.097 - 0.118
# epoch:1 | 0.097 - 0.1
# epoch:2 | 0.097 - 0.101
# epoch:3 | 0.097 - 0.125
# epoch:4 | 0.097 - 0.147
# epoch:5 | 0.097 - 0.186
# epoch:6 | 0.097 - 0.208
# epoch:7 | 0.097 - 0.229
# epoch:8 | 0.097 - 0.241
# epoch:9 | 0.097 - 0.27
# epoch:10 | 0.097 - 0.298
# epoch:11 | 0.097 - 0.312
# epoch:12 | 0.097 - 0.331
# epoch:13 | 0.097 - 0.351
# epoch:14 | 0.097 - 0.352
# epoch:15 | 0.097 - 0.385
# epoch:16 | 0.097 - 0.382
# epoch:17 | 0.097 - 0.399
# epoch:18 | 0.097 - 0.412
# epoch:19 | 0.097 - 0.432
# No handles with labels found to put in legend.
# ============== 3/16 ==============
# epoch:0 | 0.137 - 0.096
# epoch:1 | 0.461 - 0.122
# epoch:2 | 0.57 - 0.174
# epoch:3 | 0.666 - 0.224
# epoch:4 | 0.71 - 0.262
# epoch:5 | 0.798 - 0.307
# epoch:6 | 0.813 - 0.351
# epoch:7 | 0.85 - 0.374
# epoch:8 | 0.873 - 0.416
# epoch:9 | 0.898 - 0.455
# epoch:10 | 0.93 - 0.482
# epoch:11 | 0.936 - 0.511
# epoch:12 | 0.96 - 0.531
# epoch:13 | 0.972 - 0.557
# epoch:14 | 0.976 - 0.574
# epoch:15 | 0.98 - 0.598
# epoch:16 | 0.982 - 0.61
# epoch:17 | 0.987 - 0.628
# No handles with labels found to put in legend.
# epoch:18 | 0.99 - 0.639
# epoch:19 | 0.99 - 0.653
# ============== 4/16 ==============
# epoch:0 | 0.137 - 0.1
# epoch:1 | 0.235 - 0.122
# epoch:2 | 0.323 - 0.176
# epoch:3 | 0.419 - 0.239
# epoch:4 | 0.484 - 0.333
# epoch:5 | 0.553 - 0.394
# epoch:6 | 0.61 - 0.444
# epoch:7 | 0.635 - 0.492
# epoch:8 | 0.685 - 0.534
# epoch:9 | 0.702 - 0.57
# epoch:10 | 0.733 - 0.591
# epoch:11 | 0.753 - 0.625
# epoch:12 | 0.767 - 0.65
# epoch:13 | 0.782 - 0.677
# epoch:14 | 0.802 - 0.695
# epoch:15 | 0.81 - 0.726
# epoch:16 | 0.814 - 0.741
# epoch:17 | 0.827 - 0.763
# No handles with labels found to put in legend.
# epoch:18 | 0.848 - 0.77
# epoch:19 | 0.855 - 0.785
# ============== 5/16 ==============
# epoch:0 | 0.126 - 0.119
# epoch:1 | 0.125 - 0.14
# epoch:2 | 0.133 - 0.233
# epoch:3 | 0.133 - 0.354
# epoch:4 | 0.148 - 0.47
# epoch:5 | 0.15 - 0.538
# epoch:6 | 0.15 - 0.599
# epoch:7 | 0.163 - 0.646
# epoch:8 | 0.175 - 0.682
# epoch:9 | 0.192 - 0.714
# epoch:10 | 0.203 - 0.726
# epoch:11 | 0.219 - 0.737
# epoch:12 | 0.24 - 0.76
# epoch:13 | 0.247 - 0.778
# epoch:14 | 0.26 - 0.799
# epoch:15 | 0.273 - 0.812
# epoch:16 | 0.289 - 0.83
# epoch:17 | 0.3 - 0.842
# epoch:18 | 0.293 - 0.854
# No handles with labels found to put in legend.
# epoch:19 | 0.309 - 0.867
# ============== 6/16 ==============
# epoch:0 | 0.123 - 0.097
# epoch:1 | 0.117 - 0.221
# epoch:2 | 0.117 - 0.44
# epoch:3 | 0.117 - 0.585
# epoch:4 | 0.117 - 0.672
# epoch:5 | 0.117 - 0.726
# epoch:6 | 0.117 - 0.771
# epoch:7 | 0.117 - 0.8
# epoch:8 | 0.117 - 0.823
# epoch:9 | 0.117 - 0.844
# epoch:10 | 0.117 - 0.864
# epoch:11 | 0.117 - 0.878
# epoch:12 | 0.167 - 0.888
# epoch:13 | 0.156 - 0.897
# epoch:14 | 0.168 - 0.906
# epoch:15 | 0.138 - 0.911
# epoch:16 | 0.134 - 0.92
# epoch:17 | 0.134 - 0.921
# epoch:18 | 0.159 - 0.932
# No handles with labels found to put in legend.
# epoch:19 | 0.15 - 0.937
# ============== 7/16 ==============
# epoch:0 | 0.117 - 0.103
# epoch:1 | 0.117 - 0.228
# epoch:2 | 0.117 - 0.561
# epoch:3 | 0.117 - 0.734
# epoch:4 | 0.117 - 0.799
# epoch:5 | 0.117 - 0.825
# epoch:6 | 0.117 - 0.853
# epoch:7 | 0.117 - 0.881
# epoch:8 | 0.117 - 0.904
# epoch:9 | 0.117 - 0.912
# epoch:10 | 0.117 - 0.933
# epoch:11 | 0.117 - 0.95
# epoch:12 | 0.117 - 0.962
# epoch:13 | 0.117 - 0.964
# epoch:14 | 0.117 - 0.97
# epoch:15 | 0.117 - 0.98
# epoch:16 | 0.117 - 0.981
# epoch:17 | 0.117 - 0.985
# epoch:18 | 0.117 - 0.987
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.988
# ============== 8/16 ==============
# epoch:0 | 0.119 - 0.104
# epoch:1 | 0.097 - 0.159
# epoch:2 | 0.117 - 0.666
# epoch:3 | 0.117 - 0.751
# epoch:4 | 0.117 - 0.791
# epoch:5 | 0.117 - 0.837
# epoch:6 | 0.117 - 0.883
# epoch:7 | 0.117 - 0.916
# epoch:8 | 0.117 - 0.944
# epoch:9 | 0.117 - 0.962
# epoch:10 | 0.117 - 0.972
# epoch:11 | 0.117 - 0.984
# epoch:12 | 0.117 - 0.99
# epoch:13 | 0.117 - 0.993
# epoch:14 | 0.117 - 0.995
# epoch:15 | 0.117 - 0.997
# epoch:16 | 0.117 - 0.998
# epoch:17 | 0.117 - 0.997
# epoch:18 | 0.117 - 0.999
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 1.0
# ============== 9/16 ==============
# epoch:0 | 0.1 - 0.096
# epoch:1 | 0.116 - 0.597
# epoch:2 | 0.116 - 0.784
# epoch:3 | 0.116 - 0.86
# epoch:4 | 0.116 - 0.916
# epoch:5 | 0.116 - 0.946
# epoch:6 | 0.116 - 0.961
# epoch:7 | 0.116 - 0.979
# epoch:8 | 0.116 - 0.984
# epoch:9 | 0.116 - 0.989
# epoch:10 | 0.116 - 0.991
# epoch:11 | 0.116 - 0.992
# epoch:12 | 0.116 - 0.994
# epoch:13 | 0.117 - 0.996
# epoch:14 | 0.117 - 0.998
# epoch:15 | 0.117 - 0.999
# epoch:16 | 0.117 - 0.999
# epoch:17 | 0.117 - 0.994
# epoch:18 | 0.117 - 0.999
# epoch:19 | 0.116 - 0.999
# No handles with labels found to put in legend.
# ============== 10/16 ==============
# epoch:0 | 0.092 - 0.114
# epoch:1 | 0.105 - 0.488
# epoch:2 | 0.116 - 0.758
# epoch:3 | 0.117 - 0.801
# epoch:4 | 0.117 - 0.851
# epoch:5 | 0.116 - 0.874
# epoch:6 | 0.116 - 0.828
# epoch:7 | 0.116 - 0.889
# epoch:8 | 0.116 - 0.891
# epoch:9 | 0.116 - 0.943
# epoch:10 | 0.116 - 0.982
# epoch:11 | 0.116 - 0.99
# epoch:12 | 0.116 - 0.992
# epoch:13 | 0.116 - 0.981
# epoch:14 | 0.116 - 0.993
# epoch:15 | 0.116 - 0.995
# epoch:16 | 0.116 - 0.998
# epoch:17 | 0.116 - 0.998
# epoch:18 | 0.116 - 0.997
# epoch:19 | 0.116 - 0.997
# No handles with labels found to put in legend.
# ============== 11/16 ==============
# epoch:0 | 0.116 - 0.117
# epoch:1 | 0.116 - 0.692
# epoch:2 | 0.116 - 0.815
# epoch:3 | 0.116 - 0.828
# epoch:4 | 0.116 - 0.851
# epoch:5 | 0.116 - 0.869
# epoch:6 | 0.116 - 0.879
# epoch:7 | 0.116 - 0.863
# epoch:8 | 0.116 - 0.968
# epoch:9 | 0.116 - 0.965
# epoch:10 | 0.116 - 0.989
# epoch:11 | 0.117 - 0.929
# epoch:12 | 0.117 - 0.954
# epoch:13 | 0.117 - 0.99
# epoch:14 | 0.117 - 0.992
# epoch:15 | 0.117 - 0.996
# epoch:16 | 0.117 - 0.996
# epoch:17 | 0.117 - 0.996
# epoch:18 | 0.117 - 0.996
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.996
# ============== 12/16 ==============
# epoch:0 | 0.097 - 0.198
# epoch:1 | 0.116 - 0.433
# epoch:2 | 0.116 - 0.598
# epoch:3 | 0.116 - 0.648
# epoch:4 | 0.116 - 0.674
# epoch:5 | 0.116 - 0.666
# epoch:6 | 0.116 - 0.712
# epoch:7 | 0.116 - 0.62
# epoch:8 | 0.116 - 0.704
# epoch:9 | 0.116 - 0.705
# epoch:10 | 0.116 - 0.71
# epoch:11 | 0.116 - 0.799
# epoch:12 | 0.117 - 0.803
# epoch:13 | 0.117 - 0.798
# epoch:14 | 0.117 - 0.767
# epoch:15 | 0.117 - 0.886
# epoch:16 | 0.117 - 0.814
# epoch:17 | 0.117 - 0.898
# epoch:18 | 0.117 - 0.9
# epoch:19 | 0.117 - 0.899
# No handles with labels found to put in legend.
# ============== 13/16 ==============
# epoch:0 | 0.093 - 0.244
# epoch:1 | 0.117 - 0.556
# epoch:2 | 0.117 - 0.375
# epoch:3 | 0.117 - 0.592
# epoch:4 | 0.117 - 0.601
# epoch:5 | 0.117 - 0.613
# epoch:6 | 0.117 - 0.624
# epoch:7 | 0.117 - 0.63
# epoch:8 | 0.116 - 0.619
# epoch:9 | 0.117 - 0.675
# epoch:10 | 0.117 - 0.787
# epoch:11 | 0.117 - 0.713
# epoch:12 | 0.116 - 0.793
# epoch:13 | 0.116 - 0.804
# epoch:14 | 0.116 - 0.809
# epoch:15 | 0.116 - 0.808
# epoch:16 | 0.116 - 0.807
# epoch:17 | 0.116 - 0.575
# epoch:18 | 0.116 - 0.809
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.811
# ============== 14/16 ==============
# epoch:0 | 0.117 - 0.185
# epoch:1 | 0.117 - 0.432
# epoch:2 | 0.116 - 0.216
# epoch:3 | 0.116 - 0.386
# epoch:4 | 0.116 - 0.468
# epoch:5 | 0.116 - 0.496
# epoch:6 | 0.116 - 0.512
# epoch:7 | 0.117 - 0.52
# epoch:8 | 0.117 - 0.511
# epoch:9 | 0.117 - 0.519
# epoch:10 | 0.117 - 0.521
# epoch:11 | 0.117 - 0.512
# epoch:12 | 0.117 - 0.473
# epoch:13 | 0.117 - 0.499
# epoch:14 | 0.117 - 0.51
# epoch:15 | 0.117 - 0.518
# epoch:16 | 0.116 - 0.524
# epoch:17 | 0.117 - 0.606
# epoch:18 | 0.117 - 0.6
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.606
# ============== 15/16 ==============
# epoch:0 | 0.099 - 0.099
# epoch:1 | 0.094 - 0.119
# epoch:2 | 0.105 - 0.369
# epoch:3 | 0.105 - 0.46
# epoch:4 | 0.105 - 0.485
# epoch:5 | 0.105 - 0.456
# epoch:6 | 0.105 - 0.49
# epoch:7 | 0.105 - 0.49
# epoch:8 | 0.105 - 0.492
# epoch:9 | 0.105 - 0.495
# epoch:10 | 0.105 - 0.497
# epoch:11 | 0.105 - 0.495
# epoch:12 | 0.116 - 0.498
# epoch:13 | 0.116 - 0.496
# epoch:14 | 0.117 - 0.471
# epoch:15 | 0.117 - 0.499
# epoch:16 | 0.117 - 0.499
# epoch:17 | 0.117 - 0.499
# epoch:18 | 0.117 - 0.5
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.5
# ============== 16/16 ==============
# epoch:0 | 0.105 - 0.161
# epoch:1 | 0.117 - 0.278
# epoch:2 | 0.117 - 0.457
# epoch:3 | 0.117 - 0.492
# epoch:4 | 0.117 - 0.508
# epoch:5 | 0.117 - 0.511
# epoch:6 | 0.117 - 0.506
# epoch:7 | 0.117 - 0.51
# epoch:8 | 0.117 - 0.52
# epoch:9 | 0.117 - 0.523
# epoch:10 | 0.117 - 0.517
# epoch:11 | 0.117 - 0.528
# epoch:12 | 0.117 - 0.529
# epoch:13 | 0.117 - 0.525
# epoch:14 | 0.117 - 0.527
# epoch:15 | 0.117 - 0.521
# epoch:16 | 0.117 - 0.612
# epoch:17 | 0.117 - 0.606
# epoch:18 | 0.117 - 0.587
# epoch:19 | 0.117 - 0.619

# %% [markdown]
# ## Weight decay

# %%
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（荷重減衰）の設定 =======================
#weight_decay_lambda = 0 # weight decayを使用しない場合
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.08, test acc:0.0835
# epoch:1, train acc:0.08333333333333333, test acc:0.0914
# epoch:2, train acc:0.09333333333333334, test acc:0.0977
# epoch:3, train acc:0.11666666666666667, test acc:0.1057
# epoch:4, train acc:0.13, test acc:0.1178
# epoch:5, train acc:0.18, test acc:0.1316
# epoch:6, train acc:0.20333333333333334, test acc:0.1481
# epoch:7, train acc:0.23333333333333334, test acc:0.16
# epoch:8, train acc:0.25333333333333335, test acc:0.1675
# epoch:9, train acc:0.2833333333333333, test acc:0.1729
# epoch:10, train acc:0.31, test acc:0.192
# epoch:11, train acc:0.32666666666666666, test acc:0.2052
# epoch:12, train acc:0.35333333333333333, test acc:0.2167
# epoch:13, train acc:0.36, test acc:0.2252
# epoch:14, train acc:0.38333333333333336, test acc:0.2517
# epoch:15, train acc:0.37333333333333335, test acc:0.2495
# epoch:16, train acc:0.4, test acc:0.2643
# epoch:17, train acc:0.43, test acc:0.2751
# epoch:18, train acc:0.4066666666666667, test acc:0.266
# epoch:19, train acc:0.45666666666666667, test acc:0.3004
# epoch:20, train acc:0.4766666666666667, test acc:0.3288
# epoch:21, train acc:0.47333333333333333, test acc:0.3457
# epoch:22, train acc:0.4766666666666667, test acc:0.3554
# epoch:23, train acc:0.49666666666666665, test acc:0.3722
# epoch:24, train acc:0.5, test acc:0.3796
# epoch:25, train acc:0.5033333333333333, test acc:0.3902
# epoch:26, train acc:0.5066666666666667, test acc:0.4077
# epoch:27, train acc:0.5066666666666667, test acc:0.4121
# epoch:28, train acc:0.53, test acc:0.4331
# epoch:29, train acc:0.55, test acc:0.434
# epoch:30, train acc:0.55, test acc:0.4311
# epoch:31, train acc:0.5433333333333333, test acc:0.436
# epoch:32, train acc:0.5666666666666667, test acc:0.4544
# epoch:33, train acc:0.5733333333333334, test acc:0.4506
# epoch:34, train acc:0.57, test acc:0.4535
# epoch:35, train acc:0.5966666666666667, test acc:0.4809
# epoch:36, train acc:0.6233333333333333, test acc:0.4874
# epoch:37, train acc:0.63, test acc:0.5063
# epoch:38, train acc:0.63, test acc:0.5077
# epoch:39, train acc:0.6266666666666667, test acc:0.5114
# epoch:40, train acc:0.6366666666666667, test acc:0.5221
# epoch:41, train acc:0.6366666666666667, test acc:0.5279
# epoch:42, train acc:0.6433333333333333, test acc:0.5335
# epoch:43, train acc:0.6533333333333333, test acc:0.5461
# epoch:44, train acc:0.6666666666666666, test acc:0.5675
# epoch:45, train acc:0.6633333333333333, test acc:0.5705
# epoch:46, train acc:0.6733333333333333, test acc:0.5788
# epoch:47, train acc:0.6866666666666666, test acc:0.5913
# epoch:48, train acc:0.7033333333333334, test acc:0.5936
# epoch:49, train acc:0.69, test acc:0.6045
# epoch:50, train acc:0.6866666666666666, test acc:0.5987
# epoch:51, train acc:0.7233333333333334, test acc:0.6019
# epoch:52, train acc:0.7366666666666667, test acc:0.6122
# epoch:53, train acc:0.74, test acc:0.6145
# epoch:54, train acc:0.75, test acc:0.6204
# epoch:55, train acc:0.76, test acc:0.6258
# epoch:56, train acc:0.76, test acc:0.6282
# epoch:57, train acc:0.7533333333333333, test acc:0.611
# epoch:58, train acc:0.7466666666666667, test acc:0.6154
# epoch:59, train acc:0.74, test acc:0.6132
# epoch:60, train acc:0.7366666666666667, test acc:0.5982
# epoch:61, train acc:0.75, test acc:0.612
# epoch:62, train acc:0.7466666666666667, test acc:0.614
# epoch:63, train acc:0.7533333333333333, test acc:0.6244
# epoch:64, train acc:0.7566666666666667, test acc:0.6319
# epoch:65, train acc:0.7633333333333333, test acc:0.6339
# epoch:66, train acc:0.7666666666666667, test acc:0.6314
# epoch:67, train acc:0.7733333333333333, test acc:0.6461
# epoch:68, train acc:0.78, test acc:0.6397
# epoch:69, train acc:0.77, test acc:0.6369
# epoch:70, train acc:0.7666666666666667, test acc:0.6486
# epoch:71, train acc:0.7933333333333333, test acc:0.6597
# epoch:72, train acc:0.8, test acc:0.6678
# epoch:73, train acc:0.8033333333333333, test acc:0.6665
# epoch:74, train acc:0.7866666666666666, test acc:0.6578
# epoch:75, train acc:0.77, test acc:0.6539
# epoch:76, train acc:0.7866666666666666, test acc:0.664
# epoch:77, train acc:0.7966666666666666, test acc:0.6665
# epoch:78, train acc:0.8, test acc:0.6735
# epoch:79, train acc:0.81, test acc:0.6726
# epoch:80, train acc:0.7933333333333333, test acc:0.6608
# epoch:81, train acc:0.81, test acc:0.6783
# epoch:82, train acc:0.81, test acc:0.6817
# epoch:83, train acc:0.8133333333333334, test acc:0.6855
# epoch:84, train acc:0.8066666666666666, test acc:0.6796
# epoch:85, train acc:0.8133333333333334, test acc:0.6813
# epoch:86, train acc:0.81, test acc:0.6664
# epoch:87, train acc:0.8133333333333334, test acc:0.6836
# epoch:88, train acc:0.81, test acc:0.6807
# epoch:89, train acc:0.81, test acc:0.6805
# epoch:90, train acc:0.8266666666666667, test acc:0.6848
# epoch:91, train acc:0.8233333333333334, test acc:0.6914
# epoch:92, train acc:0.81, test acc:0.6834
# epoch:93, train acc:0.8166666666666667, test acc:0.6799
# epoch:94, train acc:0.81, test acc:0.6813
# epoch:95, train acc:0.83, test acc:0.6849
# epoch:96, train acc:0.8233333333333334, test acc:0.6946
# epoch:97, train acc:0.82, test acc:0.6809
# epoch:98, train acc:0.82, test acc:0.6732
# epoch:99, train acc:0.82, test acc:0.681
# epoch:100, train acc:0.8133333333333334, test acc:0.6692
# epoch:101, train acc:0.8233333333333334, test acc:0.6872
# epoch:102, train acc:0.8333333333333334, test acc:0.6864
# epoch:103, train acc:0.82, test acc:0.6905
# epoch:104, train acc:0.8366666666666667, test acc:0.6847
# epoch:105, train acc:0.8366666666666667, test acc:0.6907
# epoch:106, train acc:0.8433333333333334, test acc:0.6894
# epoch:107, train acc:0.8233333333333334, test acc:0.6856
# epoch:108, train acc:0.8433333333333334, test acc:0.6874
# epoch:109, train acc:0.8366666666666667, test acc:0.6993
# epoch:110, train acc:0.8366666666666667, test acc:0.695
# epoch:111, train acc:0.8333333333333334, test acc:0.6898
# epoch:112, train acc:0.83, test acc:0.6937
# epoch:113, train acc:0.83, test acc:0.7006
# epoch:114, train acc:0.8333333333333334, test acc:0.7036
# epoch:115, train acc:0.8466666666666667, test acc:0.7053
# epoch:116, train acc:0.8433333333333334, test acc:0.7113
# epoch:117, train acc:0.8333333333333334, test acc:0.7053
# epoch:118, train acc:0.8333333333333334, test acc:0.6886
# epoch:119, train acc:0.84, test acc:0.7001
# epoch:120, train acc:0.8433333333333334, test acc:0.689
# epoch:121, train acc:0.8366666666666667, test acc:0.7002
# epoch:122, train acc:0.8433333333333334, test acc:0.7047
# epoch:123, train acc:0.84, test acc:0.6987
# epoch:124, train acc:0.8433333333333334, test acc:0.7049
# epoch:125, train acc:0.8433333333333334, test acc:0.6877
# epoch:126, train acc:0.85, test acc:0.6924
# epoch:127, train acc:0.84, test acc:0.6897
# epoch:128, train acc:0.8333333333333334, test acc:0.7025
# epoch:129, train acc:0.8366666666666667, test acc:0.6934
# epoch:130, train acc:0.8466666666666667, test acc:0.701
# epoch:131, train acc:0.8366666666666667, test acc:0.6981
# epoch:132, train acc:0.8366666666666667, test acc:0.6929
# epoch:133, train acc:0.8366666666666667, test acc:0.6931
# epoch:134, train acc:0.84, test acc:0.6929
# epoch:135, train acc:0.84, test acc:0.7
# epoch:136, train acc:0.85, test acc:0.6995
# epoch:137, train acc:0.8333333333333334, test acc:0.6924
# epoch:138, train acc:0.83, test acc:0.7081
# epoch:139, train acc:0.8433333333333334, test acc:0.7048
# epoch:140, train acc:0.8466666666666667, test acc:0.692
# epoch:141, train acc:0.84, test acc:0.6835
# epoch:142, train acc:0.85, test acc:0.6901
# epoch:143, train acc:0.8433333333333334, test acc:0.707
# epoch:144, train acc:0.8433333333333334, test acc:0.6859
# epoch:145, train acc:0.8466666666666667, test acc:0.7032
# epoch:146, train acc:0.84, test acc:0.6942
# epoch:147, train acc:0.8533333333333334, test acc:0.7079
# epoch:148, train acc:0.8466666666666667, test acc:0.7054
# epoch:149, train acc:0.8466666666666667, test acc:0.7063
# epoch:150, train acc:0.85, test acc:0.6943
# epoch:151, train acc:0.8466666666666667, test acc:0.6935
# epoch:152, train acc:0.8433333333333334, test acc:0.6935
# epoch:153, train acc:0.84, test acc:0.7041
# epoch:154, train acc:0.8533333333333334, test acc:0.6992
# epoch:155, train acc:0.85, test acc:0.7055
# epoch:156, train acc:0.8466666666666667, test acc:0.7078
# epoch:157, train acc:0.8466666666666667, test acc:0.6987
# epoch:158, train acc:0.85, test acc:0.7144
# epoch:159, train acc:0.84, test acc:0.7099
# epoch:160, train acc:0.85, test acc:0.7063
# epoch:161, train acc:0.8533333333333334, test acc:0.7112
# epoch:162, train acc:0.8466666666666667, test acc:0.7105
# epoch:163, train acc:0.85, test acc:0.7022
# epoch:164, train acc:0.85, test acc:0.6932
# epoch:165, train acc:0.8466666666666667, test acc:0.698
# epoch:166, train acc:0.8566666666666667, test acc:0.6951
# epoch:167, train acc:0.85, test acc:0.7127
# epoch:168, train acc:0.8466666666666667, test acc:0.6926
# epoch:169, train acc:0.8433333333333334, test acc:0.6909
# epoch:170, train acc:0.8433333333333334, test acc:0.6944
# epoch:171, train acc:0.84, test acc:0.7016
# epoch:172, train acc:0.85, test acc:0.7078
# epoch:173, train acc:0.8433333333333334, test acc:0.7129
# epoch:174, train acc:0.8533333333333334, test acc:0.7007
# epoch:175, train acc:0.8333333333333334, test acc:0.6941
# epoch:176, train acc:0.8433333333333334, test acc:0.7036
# epoch:177, train acc:0.8566666666666667, test acc:0.7036
# epoch:178, train acc:0.8466666666666667, test acc:0.7003
# epoch:179, train acc:0.8566666666666667, test acc:0.7135
# epoch:180, train acc:0.8566666666666667, test acc:0.705
# epoch:181, train acc:0.85, test acc:0.7019
# epoch:182, train acc:0.8533333333333334, test acc:0.7064
# epoch:183, train acc:0.8533333333333334, test acc:0.7084
# epoch:184, train acc:0.8566666666666667, test acc:0.7015
# epoch:185, train acc:0.8666666666666667, test acc:0.7069
# epoch:186, train acc:0.86, test acc:0.7063
# epoch:187, train acc:0.8566666666666667, test acc:0.7001
# epoch:188, train acc:0.8566666666666667, test acc:0.7037
# epoch:189, train acc:0.8533333333333334, test acc:0.6925
# epoch:190, train acc:0.85, test acc:0.6995
# epoch:191, train acc:0.8633333333333333, test acc:0.7021
# epoch:192, train acc:0.8633333333333333, test acc:0.7035
# epoch:193, train acc:0.8666666666666667, test acc:0.7051
# epoch:194, train acc:0.8633333333333333, test acc:0.7114
# epoch:195, train acc:0.8533333333333334, test acc:0.692
# epoch:196, train acc:0.8633333333333333, test acc:0.7083
# epoch:197, train acc:0.8666666666666667, test acc:0.7129
# epoch:198, train acc:0.87, test acc:0.7129
# epoch:199, train acc:0.87, test acc:0.7046
# epoch:200, train acc:0.8633333333333333, test acc:0.7007

# %% [markdown]
# ## Dropout

# %%
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# Dropuoutの有無、割り合いの設定 ========================
use_dropout = True  # Dropoutなしのときの場合はFalseに
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.311469473777433
# === epoch:1, train acc:0.10333333333333333, test acc:0.0917 ===
# train loss:2.3170632508886566
# train loss:2.309004920731901
# train loss:2.316908928981916
# === epoch:2, train acc:0.1, test acc:0.0918 ===
# train loss:2.3236548774611148
# train loss:2.302720755717671
# train loss:2.3083469683235025
# === epoch:3, train acc:0.1, test acc:0.0924 ===
# train loss:2.28458877833924
# train loss:2.3112385956286774
# train loss:2.3029293374002497
# === epoch:4, train acc:0.1, test acc:0.0932 ===
# train loss:2.2961089952253646
# train loss:2.3185143225740865
# train loss:2.3062160760437562
# === epoch:5, train acc:0.1, test acc:0.0937 ===
# train loss:2.295814672238027
# train loss:2.294634020559202
# train loss:2.3077199200780445
# === epoch:6, train acc:0.1, test acc:0.0935 ===
# train loss:2.314641929068552
# train loss:2.302720858538614
# train loss:2.30171191739079
# === epoch:7, train acc:0.1, test acc:0.0951 ===
# train loss:2.3017068311531967
# train loss:2.3082511843964895
# train loss:2.292769311156849
# === epoch:8, train acc:0.1, test acc:0.0953 ===
# train loss:2.311814324015628
# train loss:2.2933087496052313
# train loss:2.2999650492391397
# === epoch:9, train acc:0.1, test acc:0.0953 ===
# train loss:2.2940002117001796
# train loss:2.2959900794719568
# train loss:2.2846585551338667
# === epoch:10, train acc:0.1, test acc:0.0951 ===
# train loss:2.29315715697477
# train loss:2.3001664006003253
# train loss:2.3061544971583254
# === epoch:11, train acc:0.09666666666666666, test acc:0.0968 ===
# train loss:2.298961251994585
# train loss:2.2914596069342754
# train loss:2.3039709748168957
# === epoch:12, train acc:0.09666666666666666, test acc:0.1001 ===
# train loss:2.2977008571217694
# train loss:2.295053899191237
# train loss:2.298175633735542
# === epoch:13, train acc:0.09333333333333334, test acc:0.1024 ===
# train loss:2.291913829012466
# train loss:2.2970000217973943
# train loss:2.295187494873516
# === epoch:14, train acc:0.10333333333333333, test acc:0.1086 ===
# train loss:2.2945096604697204
# train loss:2.285133442313234
# train loss:2.290827594725827
# === epoch:15, train acc:0.10666666666666667, test acc:0.1116 ===
# train loss:2.2865482821743663
# train loss:2.295050633503231
# train loss:2.2828330279446325
# === epoch:16, train acc:0.10666666666666667, test acc:0.1154 ===
# train loss:2.2839021718358445
# train loss:2.295828499750726
# train loss:2.295389892348024
# === epoch:17, train acc:0.11333333333333333, test acc:0.1233 ===
# train loss:2.288319866390777
# train loss:2.293831246205274
# train loss:2.285223954520544
# === epoch:18, train acc:0.11666666666666667, test acc:0.1263 ===
# train loss:2.2883833071051027
# train loss:2.2922151879207693
# train loss:2.2858445428540506
# === epoch:19, train acc:0.12, test acc:0.1272 ===
# train loss:2.2952401894230983
# train loss:2.2886208030613866
# train loss:2.29678085075323
# === epoch:20, train acc:0.11333333333333333, test acc:0.1298 ===
# train loss:2.2951140319755576
# train loss:2.282901975077849
# train loss:2.2735948432121256
# === epoch:21, train acc:0.11333333333333333, test acc:0.1268 ===
# train loss:2.2796391194851235
# train loss:2.2746299499296008
# train loss:2.2870910054006837
# === epoch:22, train acc:0.12333333333333334, test acc:0.133 ===
# train loss:2.2789230122563855
# train loss:2.2872800789712158
# train loss:2.2806847803833126
# === epoch:23, train acc:0.12333333333333334, test acc:0.1385 ===
# train loss:2.2813117394805866
# train loss:2.2928734910044057
# train loss:2.2874344178173045
# === epoch:24, train acc:0.12666666666666668, test acc:0.1426 ===
# train loss:2.2768551623340247
# train loss:2.279614279012931
# train loss:2.291216558557827
# === epoch:25, train acc:0.12666666666666668, test acc:0.1416 ===
# train loss:2.2854750303022113
# train loss:2.279408878045933
# train loss:2.2781505403697113
# === epoch:26, train acc:0.13, test acc:0.1462 ===
# train loss:2.2901344702518243
# train loss:2.269241890713189
# train loss:2.282685326077557
# === epoch:27, train acc:0.13666666666666666, test acc:0.148 ===
# train loss:2.290282037437488
# train loss:2.2784273273776625
# train loss:2.288198651111578
# === epoch:28, train acc:0.14666666666666667, test acc:0.1528 ===
# train loss:2.282118625390004
# train loss:2.2779086065910703
# train loss:2.276178089420138
# === epoch:29, train acc:0.14666666666666667, test acc:0.1554 ===
# train loss:2.2790670988924457
# train loss:2.278053927834951
# train loss:2.2785981455137407
# === epoch:30, train acc:0.15, test acc:0.159 ===
# train loss:2.2786280135560015
# train loss:2.270671054531654
# train loss:2.2815915305558265
# === epoch:31, train acc:0.14, test acc:0.1574 ===
# train loss:2.275338419544687
# train loss:2.276942613993522
# train loss:2.279059557493554
# === epoch:32, train acc:0.14, test acc:0.1582 ===
# train loss:2.2736676266931672
# train loss:2.276198348638344
# train loss:2.2865011749322948
# === epoch:33, train acc:0.14666666666666667, test acc:0.1601 ===
# train loss:2.279459214682328
# train loss:2.285120532003758
# train loss:2.2727267307878316
# === epoch:34, train acc:0.15333333333333332, test acc:0.1622 ===
# train loss:2.2833507686164
# train loss:2.271403194473368
# train loss:2.2796693797222987
# === epoch:35, train acc:0.16333333333333333, test acc:0.1607 ===
# train loss:2.279877182028416
# train loss:2.2758619687259976
# train loss:2.2773596599883548
# === epoch:36, train acc:0.18, test acc:0.1671 ===
# train loss:2.2811843602950286
# train loss:2.2807308605929704
# train loss:2.2816260943769247
# === epoch:37, train acc:0.19333333333333333, test acc:0.1746 ===
# train loss:2.2849912134294765
# train loss:2.2557542645872983
# train loss:2.270895710192489
# === epoch:38, train acc:0.19666666666666666, test acc:0.1758 ===
# train loss:2.2688889067030416
# train loss:2.263986428054435
# train loss:2.264029620251199
# === epoch:39, train acc:0.21, test acc:0.1762 ===
# train loss:2.2786597179862103
# train loss:2.284709737406674
# train loss:2.2648410391787213
# === epoch:40, train acc:0.21333333333333335, test acc:0.1794 ===
# train loss:2.2639101380227915
# train loss:2.270702503614317
# train loss:2.2683344851776996
# === epoch:41, train acc:0.22333333333333333, test acc:0.1824 ===
# train loss:2.267505211242628
# train loss:2.27322031987556
# train loss:2.273267524750006
# === epoch:42, train acc:0.2, test acc:0.1764 ===
# train loss:2.273677664483944
# train loss:2.2639102815496948
# train loss:2.2704085530324427
# === epoch:43, train acc:0.21, test acc:0.1805 ===
# train loss:2.281181256320206
# train loss:2.266037523710385
# train loss:2.268528195510151
# === epoch:44, train acc:0.21, test acc:0.1856 ===
# train loss:2.277466736588396
# train loss:2.269307549439965
# train loss:2.271873486734667
# === epoch:45, train acc:0.21333333333333335, test acc:0.1873 ===
# train loss:2.25800762998157
# train loss:2.265536109804144
# train loss:2.264543043277464
# === epoch:46, train acc:0.20333333333333334, test acc:0.1826 ===
# train loss:2.2764247770148502
# train loss:2.2626129422600703
# train loss:2.263528367025822
# === epoch:47, train acc:0.2, test acc:0.1815 ===
# train loss:2.2648000792666996
# train loss:2.263958477586616
# train loss:2.2695857006971645
# === epoch:48, train acc:0.21, test acc:0.1855 ===
# train loss:2.2586955469508867
# train loss:2.257890293120474
# train loss:2.2608980465140744
# === epoch:49, train acc:0.21, test acc:0.1874 ===
# train loss:2.254724903114444
# train loss:2.2532758077624617
# train loss:2.2664887891848187
# === epoch:50, train acc:0.19666666666666666, test acc:0.1843 ===
# train loss:2.2678703529921758
# train loss:2.2574671671694624
# train loss:2.2664000979517853
# === epoch:51, train acc:0.19333333333333333, test acc:0.179 ===
# train loss:2.263002869365124
# train loss:2.260077484516364
# train loss:2.2609797834807206
# === epoch:52, train acc:0.21, test acc:0.1856 ===
# train loss:2.2619604469683834
# train loss:2.26418721762664
# train loss:2.2582097902319473
# === epoch:53, train acc:0.24, test acc:0.1952 ===
# train loss:2.2679430171735224
# train loss:2.2432583592047064
# train loss:2.2621453547231316
# === epoch:54, train acc:0.24333333333333335, test acc:0.1972 ===
# train loss:2.2539387655283734
# train loss:2.260886119162435
# train loss:2.2505526014412385
# === epoch:55, train acc:0.23, test acc:0.1978 ===
# train loss:2.2513895930990424
# train loss:2.258012959660946
# train loss:2.2542933492350845
# === epoch:56, train acc:0.23333333333333334, test acc:0.1998 ===
# train loss:2.259917768089624
# train loss:2.278551699101336
# train loss:2.262241025664449
# === epoch:57, train acc:0.25333333333333335, test acc:0.2059 ===
# train loss:2.24943708978059
# train loss:2.2572582035694095
# train loss:2.256595293565019
# === epoch:58, train acc:0.26666666666666666, test acc:0.2211 ===
# train loss:2.2692034899720093
# train loss:2.2665450302670127
# train loss:2.2595840828217475
# === epoch:59, train acc:0.2866666666666667, test acc:0.2271 ===
# train loss:2.2390018375057905
# train loss:2.2459985815317167
# train loss:2.265543778108501
# === epoch:60, train acc:0.2866666666666667, test acc:0.2266 ===
# train loss:2.2638942911046978
# train loss:2.2375635910738154
# train loss:2.251472088503426
# === epoch:61, train acc:0.2833333333333333, test acc:0.2258 ===
# train loss:2.249614495194949
# train loss:2.2531951555545704
# train loss:2.266777922111636
# === epoch:62, train acc:0.2733333333333333, test acc:0.216 ===
# train loss:2.253546691066445
# train loss:2.2507002453878973
# train loss:2.2514127933013173
# === epoch:63, train acc:0.2633333333333333, test acc:0.2124 ===
# train loss:2.2354093034351314
# train loss:2.2600592774184554
# train loss:2.2595780850905887
# === epoch:64, train acc:0.27, test acc:0.2185 ===
# train loss:2.251054468030593
# train loss:2.256033413433287
# train loss:2.2583777272561742
# === epoch:65, train acc:0.28, test acc:0.2224 ===
# train loss:2.255217067398413
# train loss:2.254555903424863
# train loss:2.2609469775488424
# === epoch:66, train acc:0.2833333333333333, test acc:0.2294 ===
# train loss:2.242841353116577
# train loss:2.249540689686189
# train loss:2.2238543706658103
# === epoch:67, train acc:0.2833333333333333, test acc:0.2305 ===
# train loss:2.2455322440320025
# train loss:2.2460373056579015
# train loss:2.256169670873122
# === epoch:68, train acc:0.31, test acc:0.2385 ===
# train loss:2.241694309274112
# train loss:2.263646546942051
# train loss:2.2490837898460905
# === epoch:69, train acc:0.2833333333333333, test acc:0.235 ===
# train loss:2.251495372734795
# train loss:2.2531254260876885
# train loss:2.230167405593019
# === epoch:70, train acc:0.2866666666666667, test acc:0.2311 ===
# train loss:2.2399759799149597
# train loss:2.256099311548719
# train loss:2.2462317781829646
# === epoch:71, train acc:0.30333333333333334, test acc:0.2389 ===
# train loss:2.236703011971364
# train loss:2.239182939610843
# train loss:2.248169531837517
# === epoch:72, train acc:0.3, test acc:0.2393 ===
# train loss:2.2588485387975576
# train loss:2.254359206250492
# train loss:2.247433322601117
# === epoch:73, train acc:0.30666666666666664, test acc:0.2413 ===
# train loss:2.237803372081221
# train loss:2.2286005463070238
# train loss:2.2351323665694305
# === epoch:74, train acc:0.2966666666666667, test acc:0.2372 ===
# train loss:2.2411474360774806
# train loss:2.241110063594142
# train loss:2.234675774035183
# === epoch:75, train acc:0.2966666666666667, test acc:0.234 ===
# train loss:2.244107348918247
# train loss:2.2449776897948186
# train loss:2.256578012646765
# === epoch:76, train acc:0.30333333333333334, test acc:0.2358 ===
# train loss:2.2426158308164004
# train loss:2.2194558543422103
# train loss:2.239176168328855
# === epoch:77, train acc:0.3, test acc:0.2347 ===
# train loss:2.239342743031655
# train loss:2.230110409050586
# train loss:2.257818811069771
# === epoch:78, train acc:0.32, test acc:0.2473 ===
# train loss:2.2328234675522687
# train loss:2.256306760520415
# train loss:2.2418249285931977
# === epoch:79, train acc:0.33, test acc:0.2498 ===
# train loss:2.2339362109501217
# train loss:2.249591848810326
# train loss:2.2473786487557734
# === epoch:80, train acc:0.32, test acc:0.2485 ===
# train loss:2.225788830604559
# train loss:2.235641972072252
# train loss:2.2541845417615836
# === epoch:81, train acc:0.3333333333333333, test acc:0.2535 ===
# train loss:2.2167516898658888
# train loss:2.247508749031049
# train loss:2.2490019358216964
# === epoch:82, train acc:0.3333333333333333, test acc:0.2554 ===
# train loss:2.22947596853169
# train loss:2.192334087545732
# train loss:2.2346383445285207
# === epoch:83, train acc:0.3333333333333333, test acc:0.2567 ===
# train loss:2.2237049893395398
# train loss:2.2174149128461407
# train loss:2.2135769968669283
# === epoch:84, train acc:0.32666666666666666, test acc:0.2553 ===
# train loss:2.2166875253494718
# train loss:2.218816084034238
# train loss:2.244042935627375
# === epoch:85, train acc:0.32666666666666666, test acc:0.2521 ===
# train loss:2.2377896919193185
# train loss:2.209863984196821
# train loss:2.2350867901214175
# === epoch:86, train acc:0.31333333333333335, test acc:0.2558 ===
# train loss:2.2371851365186375
# train loss:2.224480825732314
# train loss:2.2205367048681723
# === epoch:87, train acc:0.32, test acc:0.2636 ===
# train loss:2.2392447608020056
# train loss:2.2249166075317075
# train loss:2.2022485389426696
# === epoch:88, train acc:0.33, test acc:0.2632 ===
# train loss:2.2217159503521087
# train loss:2.2438380040038965
# train loss:2.2311781934869384
# === epoch:89, train acc:0.3233333333333333, test acc:0.2645 ===
# train loss:2.226887007890551
# train loss:2.2434203941867903
# train loss:2.229718908310333
# === epoch:90, train acc:0.3333333333333333, test acc:0.2709 ===
# train loss:2.2197234309849243
# train loss:2.2222411298755045
# train loss:2.2300914167899526
# === epoch:91, train acc:0.3466666666666667, test acc:0.2737 ===
# train loss:2.2107056591918233
# train loss:2.210612012490111
# train loss:2.2358875413571364
# === epoch:92, train acc:0.3433333333333333, test acc:0.277 ===
# train loss:2.2289615849826387
# train loss:2.2252528888673346
# train loss:2.228336177733974
# === epoch:93, train acc:0.35333333333333333, test acc:0.2759 ===
# train loss:2.2123038809269118
# train loss:2.214351464009986
# train loss:2.2025671134938443
# === epoch:94, train acc:0.36333333333333334, test acc:0.279 ===
# train loss:2.223094159242996
# train loss:2.229265678965009
# train loss:2.21241427210311
# === epoch:95, train acc:0.37333333333333335, test acc:0.2829 ===
# train loss:2.2403160439786354
# train loss:2.213652732832879
# train loss:2.2260240460229386
# === epoch:96, train acc:0.36666666666666664, test acc:0.284 ===
# train loss:2.2111805163019254
# train loss:2.215553707982605
# train loss:2.1720644945160474
# === epoch:97, train acc:0.35, test acc:0.2802 ===
# train loss:2.2018523352905515
# train loss:2.215420807091081
# train loss:2.2153010232286428
# === epoch:98, train acc:0.36666666666666664, test acc:0.2837 ===
# train loss:2.1998460694619
# train loss:2.214763560781867
# train loss:2.2154127695376813
# === epoch:99, train acc:0.35333333333333333, test acc:0.2827 ===
# train loss:2.210018409071999
# train loss:2.1891562144714376
# train loss:2.209104682500072
# === epoch:100, train acc:0.36, test acc:0.2834 ===
# train loss:2.193513277135245
# train loss:2.1942364298811485
# train loss:2.2280305417232906
# === epoch:101, train acc:0.37333333333333335, test acc:0.288 ===
# train loss:2.208842258479099
# train loss:2.1921824127650975
# train loss:2.1892647694435237
# === epoch:102, train acc:0.37666666666666665, test acc:0.2904 ===
# train loss:2.208308518701679
# train loss:2.235532875681464
# train loss:2.2115585812955056
# === epoch:103, train acc:0.37333333333333335, test acc:0.2896 ===
# train loss:2.1970387755378713
# train loss:2.201540146091933
# train loss:2.240591732846764
# === epoch:104, train acc:0.37666666666666665, test acc:0.2904 ===
# train loss:2.220221294234463
# train loss:2.2037208804308466
# train loss:2.2292749839195585
# === epoch:105, train acc:0.37666666666666665, test acc:0.2931 ===
# train loss:2.1737175045136627
# train loss:2.2054283837873343
# train loss:2.180045394620041
# === epoch:106, train acc:0.37, test acc:0.292 ===
# train loss:2.201354130308169
# train loss:2.2010828867187597
# train loss:2.190821198228689
# === epoch:107, train acc:0.37, test acc:0.2924 ===
# train loss:2.2017502155797057
# train loss:2.209125336167583
# train loss:2.2107636268257673
# === epoch:108, train acc:0.36666666666666664, test acc:0.2942 ===
# train loss:2.179023304560396
# train loss:2.184056916033213
# train loss:2.174689541626371
# === epoch:109, train acc:0.36666666666666664, test acc:0.2942 ===
# train loss:2.190258260578585
# train loss:2.212885482357133
# train loss:2.18577576249376
# === epoch:110, train acc:0.36666666666666664, test acc:0.2953 ===
# train loss:2.2018300412331095
# train loss:2.1892768336545605
# train loss:2.2122395475962002
# === epoch:111, train acc:0.37333333333333335, test acc:0.2959 ===
# train loss:2.18188467382316
# train loss:2.177353205723883
# train loss:2.202844639743111
# === epoch:112, train acc:0.38333333333333336, test acc:0.2956 ===
# train loss:2.2085216842471813
# train loss:2.203467263720481
# train loss:2.1645019351070016
# === epoch:113, train acc:0.36333333333333334, test acc:0.2951 ===
# train loss:2.1646088453807617
# train loss:2.172201366267664
# train loss:2.1730952597502666
# === epoch:114, train acc:0.37, test acc:0.2996 ===
# train loss:2.1919841677396183
# train loss:2.1949975581318424
# train loss:2.1921498989025214
# === epoch:115, train acc:0.37333333333333335, test acc:0.3012 ===
# train loss:2.1380904866311825
# train loss:2.18929895303266
# train loss:2.188276988554814
# === epoch:116, train acc:0.37666666666666665, test acc:0.3026 ===
# train loss:2.1780947858400017
# train loss:2.165322691740221
# train loss:2.1779416846169606
# === epoch:117, train acc:0.37666666666666665, test acc:0.3017 ===
# train loss:2.199466752048458
# train loss:2.186286064090818
# train loss:2.1697228853737376
# === epoch:118, train acc:0.37666666666666665, test acc:0.3021 ===
# train loss:2.143441337375855
# train loss:2.212558381159668
# train loss:2.155349768750466
# === epoch:119, train acc:0.38, test acc:0.305 ===
# train loss:2.192198253589915
# train loss:2.180070531216955
# train loss:2.157823495741175
# === epoch:120, train acc:0.38333333333333336, test acc:0.3062 ===
# train loss:2.1953582897566566
# train loss:2.1688969830792346
# train loss:2.159500849702175
# === epoch:121, train acc:0.38333333333333336, test acc:0.3057 ===
# train loss:2.1811274325527448
# train loss:2.1639037007624444
# train loss:2.1757081171828876
# === epoch:122, train acc:0.38333333333333336, test acc:0.3068 ===
# train loss:2.193835913963312
# train loss:2.1919060857831174
# train loss:2.1368133066390613
# === epoch:123, train acc:0.38333333333333336, test acc:0.3092 ===
# train loss:2.1460505892471993
# train loss:2.1827074634532253
# train loss:2.156594162618505
# === epoch:124, train acc:0.39, test acc:0.3116 ===
# train loss:2.1325070211092196
# train loss:2.1856072994664215
# train loss:2.166080757201795
# === epoch:125, train acc:0.39, test acc:0.314 ===
# train loss:2.1560052109038366
# train loss:2.1378689283434236
# train loss:2.143138774052893
# === epoch:126, train acc:0.38333333333333336, test acc:0.3094 ===
# train loss:2.157134782137916
# train loss:2.1537923428265078
# train loss:2.1312024953586515
# === epoch:127, train acc:0.39, test acc:0.3059 ===
# train loss:2.171871213998094
# train loss:2.1335384277347593
# train loss:2.116224301124497
# === epoch:128, train acc:0.39, test acc:0.3035 ===
# train loss:2.1499150790031614
# train loss:2.1274947883228457
# train loss:2.1277221953386047
# === epoch:129, train acc:0.39, test acc:0.3065 ===
# train loss:2.1592435820380556
# train loss:2.2037880793915985
# train loss:2.1524044674179406
# === epoch:130, train acc:0.38666666666666666, test acc:0.3093 ===
# train loss:2.174241509790323
# train loss:2.1141913583680885
# train loss:2.1442148857167047
# === epoch:131, train acc:0.38666666666666666, test acc:0.3139 ===
# train loss:2.145452453484816
# train loss:2.1429044115592344
# train loss:2.135879701692434
# === epoch:132, train acc:0.39, test acc:0.3106 ===
# train loss:2.1388285409829892
# train loss:2.1856449437594487
# train loss:2.1470066562299777
# === epoch:133, train acc:0.39, test acc:0.3126 ===
# train loss:2.1320368944684276
# train loss:2.1171450900931497
# train loss:2.1442940567514346
# === epoch:134, train acc:0.38666666666666666, test acc:0.319 ===
# train loss:2.1186241282185216
# train loss:2.1137057398194368
# train loss:2.148596429890739
# === epoch:135, train acc:0.38666666666666666, test acc:0.3208 ===
# train loss:2.105963246923916
# train loss:2.1084642973925227
# train loss:2.095756794067408
# === epoch:136, train acc:0.3933333333333333, test acc:0.3264 ===
# train loss:2.099399233881624
# train loss:2.1250962800748727
# train loss:2.085923201759349
# === epoch:137, train acc:0.39666666666666667, test acc:0.328 ===
# train loss:2.1083449115040818
# train loss:2.1427687766913466
# train loss:2.0958367186886946
# === epoch:138, train acc:0.39666666666666667, test acc:0.3241 ===
# train loss:2.122071984772576
# train loss:2.0903338855912073
# train loss:2.1181679223382726
# === epoch:139, train acc:0.3933333333333333, test acc:0.3267 ===
# train loss:2.1101438212466963
# train loss:2.1024345524940875
# train loss:2.1843107614087542
# === epoch:140, train acc:0.4033333333333333, test acc:0.3312 ===
# train loss:2.1505127214439095
# train loss:2.1186071267450144
# train loss:2.143003392319928
# === epoch:141, train acc:0.41, test acc:0.3366 ===
# train loss:2.1143203933330024
# train loss:2.0825560771073217
# train loss:2.1060357545434454
# === epoch:142, train acc:0.4066666666666667, test acc:0.3369 ===
# train loss:2.079474680583441
# train loss:2.1013923165444606
# train loss:2.132834151065321
# === epoch:143, train acc:0.41, test acc:0.3367 ===
# train loss:2.1045617061441133
# train loss:2.07707359165072
# train loss:2.089797944965184
# === epoch:144, train acc:0.41, test acc:0.3362 ===
# train loss:2.0653350217625417
# train loss:2.1016718662882856
# train loss:2.0965439530774916
# === epoch:145, train acc:0.4066666666666667, test acc:0.3417 ===
# train loss:2.1512181891581594
# train loss:2.1040023655071987
# train loss:2.089487535638948
# === epoch:146, train acc:0.41333333333333333, test acc:0.3437 ===
# train loss:2.1262764939473375
# train loss:2.112816402956108
# train loss:2.081930335457113
# === epoch:147, train acc:0.41333333333333333, test acc:0.3475 ===
# train loss:2.0854516672439267
# train loss:2.0674210934183272
# train loss:2.1461298269476687
# === epoch:148, train acc:0.4066666666666667, test acc:0.3471 ===
# train loss:2.127754685217575
# train loss:2.0741226210580863
# train loss:2.0772790748327083
# === epoch:149, train acc:0.41, test acc:0.3482 ===
# train loss:2.116768047240508
# train loss:2.089224739098956
# train loss:2.028936035946202
# === epoch:150, train acc:0.41, test acc:0.3418 ===
# train loss:2.0741663351333663
# train loss:2.0339113165830547
# train loss:2.004072843777257
# === epoch:151, train acc:0.41, test acc:0.3377 ===
# train loss:2.0720594874718916
# train loss:2.129809010143977
# train loss:2.0541471464242353
# === epoch:152, train acc:0.41, test acc:0.3417 ===
# train loss:2.0866178765864016
# train loss:2.0616775964888103
# train loss:2.078429893238478
# === epoch:153, train acc:0.4166666666666667, test acc:0.3445 ===
# train loss:2.0735603312189825
# train loss:2.016213534637392
# train loss:2.096870666439328
# === epoch:154, train acc:0.4166666666666667, test acc:0.3522 ===
# train loss:2.026813019905175
# train loss:2.094170265955546
# train loss:2.151044663603395
# === epoch:155, train acc:0.42, test acc:0.3564 ===
# train loss:2.1137376852074947
# train loss:2.071418332009884
# train loss:2.059233249482424
# === epoch:156, train acc:0.41333333333333333, test acc:0.3544 ===
# train loss:2.062744563218242
# train loss:2.086593357618576
# train loss:2.0966099051369156
# === epoch:157, train acc:0.41333333333333333, test acc:0.3508 ===
# train loss:2.0119698941075823
# train loss:2.0096360679250638
# train loss:2.076806546290797
# === epoch:158, train acc:0.41333333333333333, test acc:0.3522 ===
# train loss:2.044638499836147
# train loss:2.016674936521778
# train loss:2.0232462427316005
# === epoch:159, train acc:0.4166666666666667, test acc:0.3544 ===
# train loss:2.083576418579878
# train loss:1.9687449786151632
# train loss:2.103163144508032
# === epoch:160, train acc:0.41333333333333333, test acc:0.3543 ===
# train loss:2.100095037972949
# train loss:2.0137648580290466
# train loss:1.9952842551452488
# === epoch:161, train acc:0.41333333333333333, test acc:0.3506 ===
# train loss:2.0680038246785926
# train loss:2.004359101544342
# train loss:2.0735872539297033
# === epoch:162, train acc:0.42, test acc:0.3568 ===
# train loss:2.0332168672239903
# train loss:1.9965917813719907
# train loss:2.048833436934131
# === epoch:163, train acc:0.4266666666666667, test acc:0.3589 ===
# train loss:2.057748774044794
# train loss:2.091994671886516
# train loss:2.065260639811452
# === epoch:164, train acc:0.43666666666666665, test acc:0.3673 ===
# train loss:2.055491390301087
# train loss:2.014744385217247
# train loss:2.0068987582087536
# === epoch:165, train acc:0.44333333333333336, test acc:0.3665 ===
# train loss:1.9943853241336458
# train loss:1.9580629950245947
# train loss:2.0204282165521907
# === epoch:166, train acc:0.44333333333333336, test acc:0.3657 ===
# train loss:2.0447009407734003
# train loss:1.9910751989278053
# train loss:2.020228531160228
# === epoch:167, train acc:0.44, test acc:0.3627 ===
# train loss:2.0376260101214787
# train loss:1.9916460292517388
# train loss:2.0673513101058534
# === epoch:168, train acc:0.43666666666666665, test acc:0.3598 ===
# train loss:1.9985998706803474
# train loss:2.03966541277635
# train loss:1.9942641243994754
# === epoch:169, train acc:0.43666666666666665, test acc:0.3621 ===
# train loss:2.030297841559684
# train loss:2.0796091280031175
# train loss:2.0449775321418597
# === epoch:170, train acc:0.44666666666666666, test acc:0.3612 ===
# train loss:1.9302194626302833
# train loss:2.019485875074934
# train loss:2.005730001613646
# === epoch:171, train acc:0.44666666666666666, test acc:0.3579 ===
# train loss:2.0097317769625165
# train loss:2.015346045028756
# train loss:2.0120708150303286
# === epoch:172, train acc:0.44666666666666666, test acc:0.362 ===
# train loss:1.953058742648829
# train loss:1.9861174821031142
# train loss:2.0288817811278808
# === epoch:173, train acc:0.44, test acc:0.3599 ===
# train loss:1.9958368529251993
# train loss:1.9787938452370717
# train loss:2.052740050179043
# === epoch:174, train acc:0.44333333333333336, test acc:0.3601 ===
# train loss:2.013452745079437
# train loss:1.9175383765461285
# train loss:2.0792388718437964
# === epoch:175, train acc:0.44666666666666666, test acc:0.3654 ===
# train loss:2.0515853378518134
# train loss:1.995100887378479
# train loss:1.9970964824250956
# === epoch:176, train acc:0.45, test acc:0.3664 ===
# train loss:2.0299111650703847
# train loss:1.9588064589028387
# train loss:1.9665031780714621
# === epoch:177, train acc:0.45, test acc:0.3718 ===
# train loss:1.992232728103622
# train loss:2.021604607934795
# train loss:2.035847372237871
# === epoch:178, train acc:0.4633333333333333, test acc:0.3687 ===
# train loss:1.9257514272440783
# train loss:1.841606424768921
# train loss:1.9573065125683302
# === epoch:179, train acc:0.46, test acc:0.3636 ===
# train loss:1.9249174989617375
# train loss:1.9451370595352184
# train loss:2.049142325942614
# === epoch:180, train acc:0.46, test acc:0.3661 ===
# train loss:1.942416457016682
# train loss:1.9788605508000248
# train loss:2.0119104998547024
# === epoch:181, train acc:0.45666666666666667, test acc:0.3683 ===
# train loss:1.9445440847282185
# train loss:1.8532312857257605
# train loss:1.9515084745192817
# === epoch:182, train acc:0.46, test acc:0.3685 ===
# train loss:1.9452480120703175
# train loss:1.9416576144904456
# train loss:1.971154426925538
# === epoch:183, train acc:0.46, test acc:0.3763 ===
# train loss:1.8916620345976654
# train loss:1.9119271054324947
# train loss:1.9700328053242908
# === epoch:184, train acc:0.45666666666666667, test acc:0.3721 ===
# train loss:1.9065347148963918
# train loss:2.001390855906921
# train loss:1.9535336474646288
# === epoch:185, train acc:0.4533333333333333, test acc:0.3716 ===
# train loss:1.9219425048348473
# train loss:1.9532026791021755
# train loss:2.004200657736553
# === epoch:186, train acc:0.45666666666666667, test acc:0.3745 ===
# train loss:1.8996518410747
# train loss:1.9578435005511177
# train loss:1.8839420056419882
# === epoch:187, train acc:0.4666666666666667, test acc:0.3748 ===
# train loss:1.8934186743760637
# train loss:1.939553884185084
# train loss:1.9195918736295354
# === epoch:188, train acc:0.47333333333333333, test acc:0.3785 ===
# train loss:1.8859307017229872
# train loss:1.8254843042533553
# train loss:1.845422022655648
# === epoch:189, train acc:0.4766666666666667, test acc:0.376 ===
# train loss:1.9000523930751105
# train loss:1.892409962096937
# train loss:1.9366189383416132
# === epoch:190, train acc:0.47333333333333333, test acc:0.3779 ===
# train loss:1.8736129626652955
# train loss:1.9217001703756602
# train loss:1.810877794548046
# === epoch:191, train acc:0.48333333333333334, test acc:0.3806 ===
# train loss:1.8331385191907046
# train loss:1.822488058178714
# train loss:1.91510958397222
# === epoch:192, train acc:0.48, test acc:0.3773 ===
# train loss:1.8888595329349158
# train loss:1.9670995781186185
# train loss:1.8899627538189276
# === epoch:193, train acc:0.48333333333333334, test acc:0.3801 ===
# train loss:1.8927830544580089
# train loss:1.886225139050615
# train loss:1.9802848011329193
# === epoch:194, train acc:0.47333333333333333, test acc:0.3743 ===
# train loss:2.004680176142788
# train loss:1.8438222239380664
# train loss:1.8642469657030785
# === epoch:195, train acc:0.47333333333333333, test acc:0.3755 ===
# train loss:1.8905650457456258
# train loss:1.8119890647229826
# train loss:1.8244751965929558
# === epoch:196, train acc:0.4766666666666667, test acc:0.3771 ===
# train loss:1.7695654549560302
# train loss:1.9215805451326153
# train loss:1.8236007122190778
# === epoch:197, train acc:0.48, test acc:0.3771 ===
# train loss:1.7849486078272683
# train loss:1.917042710965378
# train loss:1.8769247222452963
# === epoch:198, train acc:0.48, test acc:0.3754 ===
# train loss:1.9428907899118975
# train loss:1.9239168196377199
# train loss:1.8749402148838328
# === epoch:199, train acc:0.4766666666666667, test acc:0.3742 ===
# train loss:1.9026232315794096
# train loss:1.7636283264480175
# train loss:1.818885581702501
# === epoch:200, train acc:0.49333333333333335, test acc:0.3834 ===
# train loss:1.8563838819140233
# train loss:1.7694268804392692
# train loss:1.7759813141006457
# === epoch:201, train acc:0.49333333333333335, test acc:0.3931 ===
# train loss:1.8497721778725214
# train loss:1.9048233693127565
# train loss:1.8965354576101097
# === epoch:202, train acc:0.49333333333333335, test acc:0.3929 ===
# train loss:1.789129870350143
# train loss:1.9345334137484402
# train loss:1.834553128983319
# === epoch:203, train acc:0.49666666666666665, test acc:0.3927 ===
# train loss:1.8699886007114208
# train loss:1.8503806056960022
# train loss:1.8404445979434467
# === epoch:204, train acc:0.49666666666666665, test acc:0.3982 ===
# train loss:1.820076682710963
# train loss:1.8132040883408067
# train loss:1.8405934907444075
# === epoch:205, train acc:0.49666666666666665, test acc:0.3945 ===
# train loss:1.733848570036565
# train loss:1.7743951694982762
# train loss:1.7614454849774817
# === epoch:206, train acc:0.49333333333333335, test acc:0.3899 ===
# train loss:1.8115896253432886
# train loss:1.8338905200445064
# train loss:1.9418099236237276
# === epoch:207, train acc:0.49, test acc:0.3908 ===
# train loss:1.8446342335193762
# train loss:1.8496990800481448
# train loss:1.8333784072686419
# === epoch:208, train acc:0.49333333333333335, test acc:0.3936 ===
# train loss:1.7327732554442008
# train loss:1.7675022030525491
# train loss:1.8486228042155821
# === epoch:209, train acc:0.49, test acc:0.3927 ===
# train loss:1.8866752854176618
# train loss:1.7458415557208895
# train loss:1.8220603542703486
# === epoch:210, train acc:0.4866666666666667, test acc:0.3938 ===
# train loss:1.8153989967180189
# train loss:1.748796086319484
# train loss:1.7393461530358099
# === epoch:211, train acc:0.4866666666666667, test acc:0.3911 ===
# train loss:1.7783706064591098
# train loss:1.8023876702683734
# train loss:1.832795058428218
# === epoch:212, train acc:0.48, test acc:0.3888 ===
# train loss:1.8127852615435984
# train loss:1.8165357379177667
# train loss:1.7402280199974784
# === epoch:213, train acc:0.47333333333333333, test acc:0.3881 ===
# train loss:1.7443480493468093
# train loss:1.8433896446205051
# train loss:1.7251523557606483
# === epoch:214, train acc:0.47333333333333333, test acc:0.3844 ===
# train loss:1.8232143038996944
# train loss:1.8184233463273605
# train loss:1.7633366418652963
# === epoch:215, train acc:0.4766666666666667, test acc:0.3847 ===
# train loss:1.8338490160220302
# train loss:1.6817472548855015
# train loss:1.7259133192618257
# === epoch:216, train acc:0.4766666666666667, test acc:0.3832 ===
# train loss:1.8027378724324277
# train loss:1.656420720456433
# train loss:1.7841405790829912
# === epoch:217, train acc:0.4766666666666667, test acc:0.3834 ===
# train loss:1.7544606983186495
# train loss:1.780526111789616
# train loss:1.780866354709026
# === epoch:218, train acc:0.48, test acc:0.382 ===
# train loss:1.8147944071694528
# train loss:1.692886921479483
# train loss:1.8185498679068142
# === epoch:219, train acc:0.48, test acc:0.3854 ===
# train loss:1.7978335653972275
# train loss:1.7768590011783727
# train loss:1.5974387398347787
# === epoch:220, train acc:0.48, test acc:0.3844 ===
# train loss:1.7570888379761516
# train loss:1.714130418682621
# train loss:1.6978849661240736
# === epoch:221, train acc:0.47333333333333333, test acc:0.3862 ===
# train loss:1.7966746972558232
# train loss:1.7322940984866768
# train loss:1.7626747526243796
# === epoch:222, train acc:0.48, test acc:0.3892 ===
# train loss:1.7784805436284037
# train loss:1.7749144973576494
# train loss:1.7349566949171875
# === epoch:223, train acc:0.48, test acc:0.3851 ===
# train loss:1.6832819136070223
# train loss:1.8003105925845098
# train loss:1.829790285845015
# === epoch:224, train acc:0.48, test acc:0.3879 ===
# train loss:1.8063872499801352
# train loss:1.8156677613605094
# train loss:1.829633210459308
# === epoch:225, train acc:0.4866666666666667, test acc:0.3914 ===
# train loss:1.810514779631265
# train loss:1.8342189801111195
# train loss:1.7713339736978677
# === epoch:226, train acc:0.49, test acc:0.3936 ===
# train loss:1.8181151594388623
# train loss:1.7297399840632774
# train loss:1.6995502644344802
# === epoch:227, train acc:0.49, test acc:0.3917 ===
# train loss:1.660150420240993
# train loss:1.7729912412897304
# train loss:1.7254003761502335
# === epoch:228, train acc:0.4866666666666667, test acc:0.3887 ===
# train loss:1.7227454680219358
# train loss:1.759316151763313
# train loss:1.6426128340157433
# === epoch:229, train acc:0.49, test acc:0.394 ===
# train loss:1.6966425023307352
# train loss:1.7884894929730226
# train loss:1.6951806213722491
# === epoch:230, train acc:0.49, test acc:0.3931 ===
# train loss:1.7231509173186692
# train loss:1.6936664829337693
# train loss:1.7100805033146398
# === epoch:231, train acc:0.49, test acc:0.3915 ===
# train loss:1.7697407134681558
# train loss:1.7789080834911772
# train loss:1.6654780320432232
# === epoch:232, train acc:0.48333333333333334, test acc:0.3911 ===
# train loss:1.6959984833910613
# train loss:1.6987889474203954
# train loss:1.6782153745213266
# === epoch:233, train acc:0.48333333333333334, test acc:0.3902 ===
# train loss:1.6421677374677595
# train loss:1.6826187624845952
# train loss:1.6587353457096718
# === epoch:234, train acc:0.48333333333333334, test acc:0.3907 ===
# train loss:1.7984886997936025
# train loss:1.7853398797492182
# train loss:1.7134448607244515
# === epoch:235, train acc:0.49, test acc:0.4029 ===
# train loss:1.7272796008860727
# train loss:1.692495757865445
# train loss:1.685617860889043
# === epoch:236, train acc:0.49666666666666665, test acc:0.4046 ===
# train loss:1.7421984249589713
# train loss:1.6662504901352058
# train loss:1.5927004549554618
# === epoch:237, train acc:0.5, test acc:0.405 ===
# train loss:1.5647748876161005
# train loss:1.5744628653401183
# train loss:1.763596139652947
# === epoch:238, train acc:0.49333333333333335, test acc:0.4033 ===
# train loss:1.7048337375131666
# train loss:1.7760359920553435
# train loss:1.7253169437151223
# === epoch:239, train acc:0.49666666666666665, test acc:0.4061 ===
# train loss:1.5688635542395264
# train loss:1.559948310305733
# train loss:1.59617946746884
# === epoch:240, train acc:0.5033333333333333, test acc:0.4069 ===
# train loss:1.7366660622888273
# train loss:1.7525543143081679
# train loss:1.687702198537519
# === epoch:241, train acc:0.5, test acc:0.4066 ===
# train loss:1.6269366940942873
# train loss:1.7203546019048606
# train loss:1.6722799498274916
# === epoch:242, train acc:0.49, test acc:0.402 ===
# train loss:1.6968255994035233
# train loss:1.6875900859903286
# train loss:1.6976080119396806
# === epoch:243, train acc:0.49333333333333335, test acc:0.4056 ===
# train loss:1.594781572403084
# train loss:1.7148418558657668
# train loss:1.5953801390620714
# === epoch:244, train acc:0.5, test acc:0.407 ===
# train loss:1.509664500669477
# train loss:1.5261286174880764
# train loss:1.582781077965146
# === epoch:245, train acc:0.49333333333333335, test acc:0.4057 ===
# train loss:1.5966178206903194
# train loss:1.7308588701777967
# train loss:1.6281939057736095
# === epoch:246, train acc:0.49333333333333335, test acc:0.4086 ===
# train loss:1.6177312992769697
# train loss:1.5702156403250767
# train loss:1.5988987751990158
# === epoch:247, train acc:0.5, test acc:0.4131 ===
# train loss:1.5863467464345433
# train loss:1.6252303158041712
# train loss:1.5524045372785265
# === epoch:248, train acc:0.5033333333333333, test acc:0.4108 ===
# train loss:1.5570273872033547
# train loss:1.5943881000051754
# train loss:1.6961937686262452
# === epoch:249, train acc:0.5033333333333333, test acc:0.4075 ===
# train loss:1.5808350931900146
# train loss:1.5166192008673238
# train loss:1.504145296890317
# === epoch:250, train acc:0.5, test acc:0.4055 ===
# train loss:1.6097718459486559
# train loss:1.6183473434912334
# train loss:1.5759517081774315
# === epoch:251, train acc:0.5033333333333333, test acc:0.4126 ===
# train loss:1.5566997876552913
# train loss:1.6021931856354776
# train loss:1.5066104180679432
# === epoch:252, train acc:0.5, test acc:0.4114 ===
# train loss:1.5792136475335294
# train loss:1.448039171732484
# train loss:1.5311856622664282
# === epoch:253, train acc:0.5033333333333333, test acc:0.4138 ===
# train loss:1.6491662650378054
# train loss:1.5518519947274125
# train loss:1.565670974456923
# === epoch:254, train acc:0.5033333333333333, test acc:0.4077 ===
# train loss:1.513146492054739
# train loss:1.5416529821114084
# train loss:1.650565291988486
# === epoch:255, train acc:0.5, test acc:0.4064 ===
# train loss:1.5641171359040964
# train loss:1.5593462620939837
# train loss:1.4966732451574374
# === epoch:256, train acc:0.5033333333333333, test acc:0.4137 ===
# train loss:1.4583364450754672
# train loss:1.70337917610794
# train loss:1.4984395418720562
# === epoch:257, train acc:0.5066666666666667, test acc:0.4168 ===
# train loss:1.5464980582220673
# train loss:1.6042799222090631
# train loss:1.5394226359299232
# === epoch:258, train acc:0.5066666666666667, test acc:0.4167 ===
# train loss:1.5656130137398736
# train loss:1.669070626814245
# train loss:1.4911774762301016
# === epoch:259, train acc:0.51, test acc:0.4186 ===
# train loss:1.6060137837667372
# train loss:1.6214526923592487
# train loss:1.5266625728923313
# === epoch:260, train acc:0.5033333333333333, test acc:0.4197 ===
# train loss:1.4603409246256709
# train loss:1.4162674988104227
# train loss:1.6189214764933597
# === epoch:261, train acc:0.5066666666666667, test acc:0.4188 ===
# train loss:1.438221493839375
# train loss:1.5712539559546435
# train loss:1.6456016830756124
# === epoch:262, train acc:0.49333333333333335, test acc:0.4134 ===
# train loss:1.606298065575758
# train loss:1.525096321998986
# train loss:1.5584304608618726
# === epoch:263, train acc:0.5066666666666667, test acc:0.4167 ===
# train loss:1.4991532005149717
# train loss:1.662391085240389
# train loss:1.497673902081996
# === epoch:264, train acc:0.51, test acc:0.4183 ===
# train loss:1.5823680477186712
# train loss:1.6122541527060161
# train loss:1.4732989830579115
# === epoch:265, train acc:0.52, test acc:0.4253 ===
# train loss:1.457651118559439
# train loss:1.4409751998360492
# train loss:1.5202999770168615
# === epoch:266, train acc:0.5166666666666667, test acc:0.4277 ===
# train loss:1.546114990004074
# train loss:1.6149595698678352
# train loss:1.475453981069547
# === epoch:267, train acc:0.5166666666666667, test acc:0.4281 ===
# train loss:1.4977171434728913
# train loss:1.4917844795242958
# train loss:1.6317363791128094
# === epoch:268, train acc:0.52, test acc:0.4314 ===
# train loss:1.5217338885523406
# train loss:1.5943836295012097
# train loss:1.4490037385148167
# === epoch:269, train acc:0.51, test acc:0.4317 ===
# train loss:1.3996047707562658
# train loss:1.5298894158375993
# train loss:1.3994932009482104
# === epoch:270, train acc:0.5166666666666667, test acc:0.4354 ===
# train loss:1.4001259342011492
# train loss:1.4780128380258881
# train loss:1.433579797715922
# === epoch:271, train acc:0.52, test acc:0.4317 ===
# train loss:1.5007476151862664
# train loss:1.4176139160395842
# train loss:1.4618388660253578
# === epoch:272, train acc:0.5033333333333333, test acc:0.428 ===
# train loss:1.4485189386055455
# train loss:1.4543006435353418
# train loss:1.3438076136832797
# === epoch:273, train acc:0.5033333333333333, test acc:0.4232 ===
# train loss:1.2846900888883637
# train loss:1.2781824164342699
# train loss:1.5294552827013757
# === epoch:274, train acc:0.5033333333333333, test acc:0.425 ===
# train loss:1.5167457768379982
# train loss:1.5922036751942918
# train loss:1.4908112149959516
# === epoch:275, train acc:0.52, test acc:0.4302 ===
# train loss:1.3476217786221314
# train loss:1.497333150560945
# train loss:1.493760174243445
# === epoch:276, train acc:0.5266666666666666, test acc:0.4358 ===
# train loss:1.3956245593005525
# train loss:1.5276331807811345
# train loss:1.4481763436138682
# === epoch:277, train acc:0.53, test acc:0.4401 ===
# train loss:1.5388093752630703
# train loss:1.396250408618801
# train loss:1.420162714815576
# === epoch:278, train acc:0.53, test acc:0.4429 ===
# train loss:1.52084861298838
# train loss:1.4087317674817166
# train loss:1.5280663089280795
# === epoch:279, train acc:0.53, test acc:0.4453 ===
# train loss:1.425660712269895
# train loss:1.5061003750610484
# train loss:1.5028393416940833
# === epoch:280, train acc:0.5333333333333333, test acc:0.4459 ===
# train loss:1.4757363555286969
# train loss:1.5459682365494054
# train loss:1.4846210269467317
# === epoch:281, train acc:0.5366666666666666, test acc:0.4443 ===
# train loss:1.3267351020886031
# train loss:1.4528177372040747
# train loss:1.4838832604354348
# === epoch:282, train acc:0.5333333333333333, test acc:0.4427 ===
# train loss:1.3913894685565078
# train loss:1.3991031841448345
# train loss:1.4564529946795803
# === epoch:283, train acc:0.54, test acc:0.444 ===
# train loss:1.5188857351287126
# train loss:1.4690416497056833
# train loss:1.4834194172429789
# === epoch:284, train acc:0.5366666666666666, test acc:0.4457 ===
# train loss:1.5089647418252772
# train loss:1.3690922830714127
# train loss:1.3757354852546515
# === epoch:285, train acc:0.53, test acc:0.441 ===
# train loss:1.4109422228557578
# train loss:1.3999007449910656
# train loss:1.5899773722527877
# === epoch:286, train acc:0.54, test acc:0.4495 ===
# train loss:1.3860212850748885
# train loss:1.4254399730548744
# train loss:1.3642607184892297
# === epoch:287, train acc:0.5433333333333333, test acc:0.4502 ===
# train loss:1.3453484097409927
# train loss:1.3074566501938787
# train loss:1.508135773994721
# === epoch:288, train acc:0.5433333333333333, test acc:0.4538 ===
# train loss:1.436699044664308
# train loss:1.3343010983002856
# train loss:1.400384701716752
# === epoch:289, train acc:0.55, test acc:0.4541 ===
# train loss:1.4164378236269872
# train loss:1.3326199219752066
# train loss:1.4951746003012047
# === epoch:290, train acc:0.5533333333333333, test acc:0.4572 ===
# train loss:1.4386495962792116
# train loss:1.3690052532851795
# train loss:1.416364012268357
# === epoch:291, train acc:0.5533333333333333, test acc:0.458 ===
# train loss:1.4342482200117892
# train loss:1.3770810621180505
# train loss:1.4246407417011755
# === epoch:292, train acc:0.5566666666666666, test acc:0.4583 ===
# train loss:1.3471940810646752
# train loss:1.257892072024542
# train loss:1.3340352521278838
# === epoch:293, train acc:0.5533333333333333, test acc:0.4566 ===
# train loss:1.3877678760546643
# train loss:1.4698221087403167
# train loss:1.3251443307899509
# === epoch:294, train acc:0.5566666666666666, test acc:0.4614 ===
# train loss:1.3415606362723738
# train loss:1.2633088746635426
# train loss:1.228789860420665
# === epoch:295, train acc:0.5533333333333333, test acc:0.4595 ===
# train loss:1.2592891132397297
# train loss:1.3813428172687838
# train loss:1.1834788936396543
# === epoch:296, train acc:0.5533333333333333, test acc:0.4605 ===
# train loss:1.3179342179840259
# train loss:1.3186193362448422
# train loss:1.3911282899328317
# === epoch:297, train acc:0.55, test acc:0.4602 ===
# train loss:1.3734249941410546
# train loss:1.2171058120135094
# train loss:1.4443676464963249
# === epoch:298, train acc:0.55, test acc:0.46 ===
# train loss:1.4476337882458374
# train loss:1.3940996608924385
# train loss:1.3732439176532585
# === epoch:299, train acc:0.5566666666666666, test acc:0.4626 ===
# train loss:1.3285232620711431
# train loss:1.2867422039998333
# train loss:1.287973145018222
# === epoch:300, train acc:0.5633333333333334, test acc:0.4651 ===
# train loss:1.4474325637402814
# train loss:1.3217704367471135
# train loss:1.2937890225691433
# === epoch:301, train acc:0.56, test acc:0.466 ===
# train loss:1.3298582586309442
# train loss:1.3501362389986964
# =============== Final Test Accuracy ===============
# test acc:0.466

# %% [markdown]
# ## ハイパーパラメータの検証

# %%
from common.util import shuffle_dataset

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 高速化のため訓練データの削減
x_train = x_train[:500]
t_train = t_train[:500]

# 検証データの分離
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# ハイパーパラメータのランダム探索======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 探索したハイパーパラメータの範囲を指定===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# グラフの描画========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.73 | lr:0.009884133017231405, weight decay:1.732593836048182e-05
# val acc:0.2 | lr:4.933802801532972e-05, weight decay:2.740009078861456e-06
# val acc:0.12 | lr:0.00029523031440339525, weight decay:4.881045069339857e-05
# val acc:0.18 | lr:1.448065863146036e-05, weight decay:6.647641355531332e-06
# val acc:0.09 | lr:0.0003031052082584207, weight decay:3.3503626293629096e-06
# val acc:0.06 | lr:5.307760688564089e-05, weight decay:4.792309021900506e-08
# val acc:0.11 | lr:1.2057624718353918e-05, weight decay:4.576586536504674e-07
# val acc:0.03 | lr:5.483111517423276e-06, weight decay:1.4169744276268925e-06
# val acc:0.42 | lr:0.0025846470065325074, weight decay:3.506306003953594e-05
# val acc:0.09 | lr:8.927750099667171e-06, weight decay:1.1934667685684862e-06
# val acc:0.13 | lr:0.00020831411978251363, weight decay:2.8112440643631817e-05
# val acc:0.27 | lr:0.0017094580078843168, weight decay:6.50591308750841e-06
# val acc:0.28 | lr:0.0022298973493474175, weight decay:4.7907248191487593e-08
# val acc:0.06 | lr:4.508539748898769e-06, weight decay:9.549013227218746e-05
# val acc:0.05 | lr:4.188071670931005e-05, weight decay:2.0800782984684758e-06
# val acc:0.13 | lr:1.8949840879705757e-06, weight decay:3.439139270624358e-05
# val acc:0.06 | lr:1.620832761340801e-05, weight decay:8.661307621232282e-08
# val acc:0.07 | lr:0.0004038470470891811, weight decay:1.7471394650343342e-07
# val acc:0.11 | lr:0.0002685046681819667, weight decay:1.6439498738084236e-07
# val acc:0.54 | lr:0.0033005309150157024, weight decay:6.660704153425466e-08
# val acc:0.13 | lr:2.003433475437719e-06, weight decay:8.073024847195684e-06
# val acc:0.06 | lr:6.308586941124675e-05, weight decay:9.971259748220722e-05
# val acc:0.15 | lr:0.00013541553436016205, weight decay:1.345546237768793e-08
# val acc:0.23 | lr:0.0016685616889727853, weight decay:4.2556392460460254e-07
# val acc:0.14 | lr:0.0009074623185590753, weight decay:5.0215721355584836e-05
# val acc:0.07 | lr:9.657067639050688e-06, weight decay:4.492821857583545e-07
# val acc:0.32 | lr:0.0021931485705446487, weight decay:2.4777918680571733e-05
# val acc:0.75 | lr:0.005404942753159887, weight decay:1.0855194169260182e-05
# val acc:0.14 | lr:2.8683752021341558e-05, weight decay:9.221032504001073e-07
# val acc:0.08 | lr:1.8880400109426868e-05, weight decay:4.87548081830664e-08
# val acc:0.16 | lr:1.1992592654323418e-05, weight decay:1.2261797252184731e-05
# val acc:0.23 | lr:6.281843752902173e-06, weight decay:3.4511240325143407e-06
# val acc:0.14 | lr:3.252205515324779e-05, weight decay:1.087653186681649e-05
# val acc:0.1 | lr:0.0002854345284745855, weight decay:1.3278086172169954e-08
# val acc:0.15 | lr:0.0008598241435677595, weight decay:1.0933247706611776e-07
# val acc:0.13 | lr:3.965169432966111e-05, weight decay:6.521913376111705e-05
# val acc:0.71 | lr:0.005421786951463202, weight decay:1.3442207952156708e-05
# val acc:0.48 | lr:0.003029897238960997, weight decay:6.930650199440766e-08
# val acc:0.08 | lr:5.1091137106544125e-05, weight decay:1.7938572777503306e-06
# val acc:0.13 | lr:5.9343137668453925e-06, weight decay:2.5527973944311004e-06
# val acc:0.52 | lr:0.00301022184490605, weight decay:2.1506828958739547e-08
# val acc:0.09 | lr:0.00033999997279289654, weight decay:9.481240085367593e-07
# val acc:0.13 | lr:2.388950846347454e-06, weight decay:2.4060314441063263e-08
# val acc:0.11 | lr:6.66633230034506e-05, weight decay:8.663675493733291e-07
# val acc:0.3 | lr:0.002063769385588935, weight decay:9.472840889185675e-08
# val acc:0.09 | lr:1.2210267755995111e-06, weight decay:1.297678363416788e-06
# val acc:0.07 | lr:4.274219959608119e-06, weight decay:1.0441497182046513e-05
# val acc:0.64 | lr:0.00636324334984323, weight decay:7.17370616043593e-06
# val acc:0.09 | lr:6.684460237547696e-06, weight decay:5.842557279524458e-06
# val acc:0.17 | lr:1.6562601704593234e-06, weight decay:7.976669318289354e-08
# val acc:0.47 | lr:0.0049751992328789, weight decay:3.1099767627302225e-06
# val acc:0.07 | lr:5.403936115822658e-06, weight decay:8.384840876556457e-07
# val acc:0.06 | lr:0.0002577463812924899, weight decay:1.117711991760864e-05
# val acc:0.04 | lr:1.1857656799953347e-06, weight decay:1.619239151820412e-05
# val acc:0.57 | lr:0.004894382343755662, weight decay:4.6930931564257456e-08
# val acc:0.35 | lr:0.001750076630818424, weight decay:4.540663420684744e-05
# val acc:0.62 | lr:0.005928295124327803, weight decay:1.3895450576987076e-05
# val acc:0.14 | lr:9.05925282824155e-05, weight decay:9.612063485855305e-07
# val acc:0.15 | lr:6.83825462067506e-06, weight decay:4.683014904868276e-05
# val acc:0.07 | lr:5.702557842189531e-05, weight decay:4.129957614361319e-06
# val acc:0.58 | lr:0.006555874252026614, weight decay:1.9929278854294417e-08
# val acc:0.13 | lr:0.000132989763279342, weight decay:5.0780037385601715e-08
# val acc:0.27 | lr:0.0022581197837284682, weight decay:4.4583120023830195e-08
# val acc:0.13 | lr:8.884653828607781e-06, weight decay:1.1249539418290907e-08
# val acc:0.06 | lr:2.282960176927536e-06, weight decay:1.028291497417007e-08
# val acc:0.1 | lr:2.788352952855211e-05, weight decay:4.343071150060391e-05
# val acc:0.05 | lr:1.4233586330219129e-05, weight decay:1.2667055238532657e-06
# val acc:0.12 | lr:7.227913937385494e-05, weight decay:2.862299532268258e-07
# val acc:0.17 | lr:0.0012541130069379973, weight decay:5.647022621010461e-07
# val acc:0.05 | lr:9.18129085999699e-06, weight decay:3.886274213929324e-05
# val acc:0.15 | lr:0.00041262772190061236, weight decay:8.928177268283924e-07
# val acc:0.06 | lr:6.750117496628789e-06, weight decay:3.279261625337708e-08
# val acc:0.19 | lr:0.0007418470666217727, weight decay:1.0112179546999032e-07
# val acc:0.15 | lr:0.0010473495255646909, weight decay:7.601970453774074e-07
# val acc:0.18 | lr:0.00015156169163426083, weight decay:1.777402434894793e-07
# val acc:0.14 | lr:1.9268414421852877e-06, weight decay:6.809889337567823e-05
# val acc:0.2 | lr:0.00032864181045871675, weight decay:8.052906127124049e-08
# val acc:0.53 | lr:0.004306589908082904, weight decay:1.4977236673137542e-06
# val acc:0.13 | lr:1.4242915559332794e-06, weight decay:5.849196031960173e-07
# val acc:0.72 | lr:0.008861137321195395, weight decay:3.8014833271374355e-06
# val acc:0.14 | lr:0.0002367777098622763, weight decay:1.7226049726424e-07
# val acc:0.07 | lr:2.5221030405824507e-05, weight decay:1.9993131870736054e-08
# val acc:0.09 | lr:3.863773017607164e-05, weight decay:6.066321216876077e-06
# val acc:0.08 | lr:5.947167728618942e-05, weight decay:7.556164053465072e-07
# val acc:0.21 | lr:0.00037062729777636514, weight decay:2.5397370331091694e-06
# val acc:0.12 | lr:2.393657813191673e-05, weight decay:2.4463077650071055e-07
# val acc:0.16 | lr:0.00010230867469893344, weight decay:2.359881286272758e-07
# val acc:0.19 | lr:0.00046324686870837916, weight decay:7.114596454747487e-05
# val acc:0.1 | lr:6.51084577404136e-05, weight decay:6.583963223226292e-06
# val acc:0.12 | lr:2.215683261078589e-05, weight decay:2.2143427193150295e-06
# val acc:0.1 | lr:3.9817077897780235e-05, weight decay:1.0288407656896081e-07
# val acc:0.08 | lr:1.8664472266835708e-05, weight decay:1.034452979963997e-08
# val acc:0.24 | lr:0.0009547822915063236, weight decay:1.1333026123867188e-08
# val acc:0.14 | lr:1.0613312362020225e-05, weight decay:4.890179764476421e-08
# val acc:0.14 | lr:0.00016595392706492566, weight decay:1.3721313650107121e-06
# val acc:0.14 | lr:0.0009353377134236696, weight decay:8.209003197625405e-07
# val acc:0.43 | lr:0.0030746017592042235, weight decay:2.039421736100172e-06
# val acc:0.34 | lr:0.002519234345236142, weight decay:1.2021968488294227e-05
# val acc:0.24 | lr:0.0012020384654912448, weight decay:1.6974485630376408e-08
# val acc:0.06 | lr:0.0002518497060019723, weight decay:3.216576092322471e-05
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.75) | lr:0.005404942753159887, weight decay:1.0855194169260182e-05
# Best-2(val acc:0.73) | lr:0.009884133017231405, weight decay:1.732593836048182e-05
# Best-3(val acc:0.72) | lr:0.008861137321195395, weight decay:3.8014833271374355e-06
# Best-4(val acc:0.71) | lr:0.005421786951463202, weight decay:1.3442207952156708e-05
# Best-5(val acc:0.64) | lr:0.00636324334984323, weight decay:7.17370616043593e-06
# Best-6(val acc:0.62) | lr:0.005928295124327803, weight decay:1.3895450576987076e-05
# Best-7(val acc:0.58) | lr:0.006555874252026614, weight decay:1.9929278854294417e-08
# Best-8(val acc:0.57) | lr:0.004894382343755662, weight decay:4.6930931564257456e-08
# Best-9(val acc:0.54) | lr:0.0033005309150157024, weight decay:6.660704153425466e-08
# Best-10(val acc:0.53) | lr:0.004306589908082904, weight decay:1.4977236673137542e-06
# Best-11(val acc:0.52) | lr:0.00301022184490605, weight decay:2.1506828958739547e-08
# Best-12(val acc:0.48) | lr:0.003029897238960997, weight decay:6.930650199440766e-08
# Best-13(val acc:0.47) | lr:0.0049751992328789, weight decay:3.1099767627302225e-06
# Best-14(val acc:0.43) | lr:0.0030746017592042235, weight decay:2.039421736100172e-06
# Best-15(val acc:0.42) | lr:0.0025846470065325074, weight decay:3.506306003953594e-05
# Best-16(val acc:0.35) | lr:0.001750076630818424, weight decay:4.540663420684744e-05
# Best-17(val acc:0.34) | lr:0.002519234345236142, weight decay:1.2021968488294227e-05
# Best-18(val acc:0.32) | lr:0.0021931485705446487, weight decay:2.4777918680571733e-05
# Best-19(val acc:0.3) | lr:0.002063769385588935, weight decay:9.472840889185675e-08
# Best-20(val acc:0.28) | lr:0.0022298973493474175, weight decay:4.7907248191487593e-08
